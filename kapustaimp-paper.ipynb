# %%
import pandas as pd
sys.path.append('/opt/rootpath/triscale')
import triscale
import sys
sys.path.append('/opt/rootpath/charts')

from charts_helper import helper
from charts_helper import deltaq

import plotly.express as px
import plotly.io as pio

# %%
df = pd.read_csv('~/charts/smartcity-tpn/oneintersection.csv')
df['tl-ttt'] = (df['tl']/df['ttt'])*100
df_algs = df[df['alg'] != 'no-preemption']
df_no_preemption = df[df['alg'] == 'no-preemption']

# %%
helper.make_boxplot_grouped(df_algs, 'perc', helper.make_title('tl-perc', 'oneintersection', 'br'),'oneintersection-perc', width=800, height=480, lang='br')
# Out:
# <div>                            <div id="8e54dbdc-9dfc-4d65-8d4b-e9d7e1e60129" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e54dbdc-9dfc-4d65-8d4b-e9d7e1e60129")) {                    Plotly.newPlot(                        "8e54dbdc-9dfc-4d65-8d4b-e9d7e1e60129",                        [{"name":"RFID","type":"box","x":["VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1"],"y":[6.414603662124973,6.387682457240085,6.001849584360153,5.989903265436746,5.965035398047435,5.940020682523272,5.891970198675489,5.857315324053536,5.742041565065659,5.648293552551442,5.454928996749486,5.410577883418988,5.402172352744151,5.307356225788318,5.21832284381084,0.0,0.0,0.0,0.0
# ...

# %%
helper.make_boxplot_grouped(df_algs, 'preemptime', helper.make_title('preemptime','oneintersection', 'br'),'oneintersection-preemptime', width=800, height=480, lang='br')
# Out:
# <div>                            <div id="4fa10469-98e1-4201-96a1-8f00caf879aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4fa10469-98e1-4201-96a1-8f00caf879aa")) {                    Plotly.newPlot(                        "4fa10469-98e1-4201-96a1-8f00caf879aa",                        [{"name":"RFID","type":"box","x":["VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1"],"y":[150.0,150.0,150.0,150.0,150.0,150.0,150.0,150.0,150.0,150.0,150.0,150.0,150.0,150.0,150.0,150.0,150.0,150.0,150.0,150.0,150.0,150.0,150.0,150.0]},{"name":"Fuzzy","type":"box","x":["VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","V
# ...

# %%
df = pd.read_csv('~/charts/smartcity-tpn/turin-gps.csv')
helper.make_map(df,9.85,helper.make_title('route','turinkap', 'br'),'turinkap-area', lang='br')
# Out:
# <div>                            <div id="08a5cf61-52f6-40b1-a5dd-a46834193425" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08a5cf61-52f6-40b1-a5dd-a46834193425")) {                    Plotly.newPlot(                        "08a5cf61-52f6-40b1-a5dd-a46834193425",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>color=\u00c1rea do Experimento<br>lat=%{lat}<br>lon=%{lon}<extra></extra>","hovertext":["\u00c1rea do Experimento","\u00c1rea do Experimento","\u00c1rea do Experimento","\u00c1rea do Experimento","\u00c1rea do Experimento",null],"lat":[45.171751,44.96828,44.96828,45.171751,45.171751,null],"legendgroup":"\u00c1rea do Experimento","line":{"color":"#1F77B4"},"lon":[7.515782,7.515782,7.773786,7.773786,7.515782,null],"mode"
# ...

# %%
df = pd.read_csv('~/charts/smartcity-tpn/turinkap.csv')
df['tl-ttt'] = (df['tl']/df['ttt'])*100
df_algs = df[df['alg'] != 'no-preemption']
df_no_preemption = df[df['alg'] == 'no-preemption']

# %%
helper.make_boxplot_grouped(df_algs, 'perc', helper.make_title('tl-perc', 'turinkap', 'br'),'turinkap-perc', width=800, height=480, lang='br')
# Out:
# <div>                            <div id="a1f2a972-96fa-466f-afa5-e0e89a326ab8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1f2a972-96fa-466f-afa5-e0e89a326ab8")) {                    Plotly.newPlot(                        "a1f2a972-96fa-466f-afa5-e0e89a326ab8",                        [{"name":"RFID","type":"box","x":["VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE1-Sin
# ...

# %%
helper.make_boxplot_grouped(df_algs, 'preemptime', helper.make_title('preemptime','turinkap', 'br'),'turinkap-preemptime', width=800, height=480, lang='br')
# Out:
# <div>                            <div id="ef95f409-da0c-41ff-9b8e-33e5206b2241" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef95f409-da0c-41ff-9b8e-33e5206b2241")) {                    Plotly.newPlot(                        "ef95f409-da0c-41ff-9b8e-33e5206b2241",                        [{"name":"RFID","type":"box","x":["VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","V
# ...

# %%
df = pd.read_csv('~/charts/smartcity-tpn/cologne-gps.csv')
helper.make_map(df,9.1,helper.make_title('route','colognekap', 'br'),'colognekap-area', lang='br')
# Out:
# <div>                            <div id="1c76db52-3c74-469a-8fa7-4f9d0368785a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c76db52-3c74-469a-8fa7-4f9d0368785a")) {                    Plotly.newPlot(                        "1c76db52-3c74-469a-8fa7-4f9d0368785a",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>color=\u00c1rea do Experimento<br>lat=%{lat}<br>lon=%{lon}<extra></extra>","hovertext":["\u00c1rea do Experimento","\u00c1rea do Experimento","\u00c1rea do Experimento","\u00c1rea do Experimento","\u00c1rea do Experimento",null],"lat":[51.109564,50.818858,50.818858,51.109564,51.109564,null],"legendgroup":"\u00c1rea do Experimento","line":{"color":"#1F77B4"},"lon":[6.800044,6.800044,7.212986,7.212986,6.800044,null],"mod
# ...

# %%
df = pd.read_csv('~/charts/smartcity-tpn/colognekap.csv')
df['tl-ttt'] = (df['tl']/df['ttt'])*100
df_algs = df[df['alg'] != 'no-preemption']
df_no_preemption = df[df['alg'] == 'no-preemption']

# %%
helper.make_boxplot_grouped(df_algs, 'perc', helper.make_title('tl-perc', 'colognekap', 'br'),'colognekap-perc', width=800, height=480, lang='br')
# Out:
# <div>                            <div id="512625b5-7bbf-4c1e-b969-da955109edb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("512625b5-7bbf-4c1e-b969-da955109edb0")) {                    Plotly.newPlot(                        "512625b5-7bbf-4c1e-b969-da955109edb0",                        [{"name":"RFID","type":"box","x":["VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","V
# ...

# %%
helper.make_boxplot_grouped(df_algs, 'preemptime', helper.make_title('preemptime','colognekap', 'br'),'colognekap-preemptime', width=800, height=480, lang='br')
# Out:
# <div>                            <div id="c328b41b-6e16-4af2-8da6-242d4f5d1103" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c328b41b-6e16-4af2-8da6-242d4f5d1103")) {                    Plotly.newPlot(                        "c328b41b-6e16-4af2-8da6-242d4f5d1103",                        [{"name":"RFID","type":"box","x":["VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE1","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE2","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","VE3","V
# ...
