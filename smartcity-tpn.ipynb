# %%
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
import numpy as np
import triscale
import geopandas as gpd
from shapely.geometry import Point, LineString, shape
import shapely.geometry

# %%
percentile = 15
confidence = 90
triscale.experiment_sizing(
    percentile, 
    confidence,
    robustness=1,
    verbose=True);
# Out:
# A one-sided bound of the 	15-th percentile
# with a confidence level of	90 %
# requires a minimum of 		25 samples
# with the worst 			1 run(s) excluded

# %%
percentile = 15 
confidence = 90 # the confidence level, in %

if (triscale.experiment_sizing(percentile,confidence,robustness=1) == 
    triscale.experiment_sizing(100-percentile,confidence,robustness=1)):
    print("It takes the same number of samples to estimate \
the \n{}-th and \n{}-th percentiles.".format(percentile, 100-percentile))
# Out:
# It takes the same number of samples to estimate the
# 15-th and
# 85-th percentiles.

# %%
marker_colors = ['#3D9970', '#FF4136', '#FF851B']
marker_patterns_shape= ['.', 'x', '+']

evs_name = {'vehev1' : 'EV1', 'vehev2' : 'EV2', 'vehev3' : 'EV3'}
algs_name = {
        'kapusta2': 'Kapusta et al (2017)',
        'allgreen': 'Hyphotetical all-green',
        'tpn3' : 'TPN',
        'no-preemption' : 'No Preemption',
        'tpn' : 'TPN (Old)',
        'kapusta': 'Kapusta et al (2017) [1st version]'
    }

scenarios = {
    'turin' : 'Turin TuSTScenario'
}

y_axis_labels = {
    'imp' : 'Time-Loss Improvement (times)',
    'perc' : 'Time-Loss Improvement (%)',
    'tl' : 'Time-Loss (s)',
    'rt' : 'Runtime (s)'
}

# %%
def make_boxplot_grouped(df,metric,title_label):
    evs = sorted(df['ev'].unique().tolist())
    algs = df['alg'].unique().tolist()

    df = df[df[metric].notnull()]

    fig = go.Figure()

    for alg in algs:
        complete_values = []
        xlabels = []
        for ev in evs:
            values = df[(df['alg'] == alg) & (df['ev'] == ev)][metric].tolist()
            xlabels += list(np.repeat(evs_name[ev], len(values)))
            complete_values += values

        fig.add_trace(go.Box(
            y=complete_values,
            x=xlabels,
            name=algs_name[alg],
            marker_color=marker_colors[algs.index(alg)]
        ))

    fig.update_layout(
        yaxis_title=y_axis_labels[metric],
        title=title_label,
        boxmode='group'
    )
    fig.show()

# %%
def make_boxplot(df,metric,title_label):
    evs = sorted(df['ev'].unique().tolist())

    fig = go.Figure()

    df = df[df[metric].notnull()]

    count = 0
    for ev in evs:
        fig.add_trace(go.Box(y=df[(df['alg'] == 'no-preemption') & (df['ev'] == ev)][metric].tolist(), name=evs_name[ev]))
        count += 1

    fig.update_layout(
        yaxis_title=y_axis_labels[metric],
        title=title_label
    )        

    fig.show()

# %%
def csv_to_geo(df):
    geometry = [Point(xy) for xy in zip(df.lon, df.lat)]
    geo_df = gpd.GeoDataFrame(df, geometry=geometry)

    geo_df2 = geo_df.groupby(['scenario', 'ev'])['geometry'].apply(lambda x: LineString(x.tolist()))
    return gpd.GeoDataFrame(geo_df2, geometry='geometry')

# %%
def make_map(geo_df,zoom,title):
    lats = []
    lons = []
    names = []
    colors = []

    for index, row in geo_df.iterrows():
        feature = row['geometry']
        name = evs_name[index[1]]

        if isinstance(feature, shapely.geometry.linestring.LineString):
            linestrings = [feature]
        elif isinstance(feature, shapely.geometry.multilinestring.MultiLineString):
            linestrings = feature.geoms
        else:
            continue
        for linestring in linestrings:
            x, y = linestring.xy
            lats = np.append(lats, y)
            lons = np.append(lons, x)
            names = np.append(names, [name]*len(y))
            lats = np.append(lats, None)
            lons = np.append(lons, None)
            names = np.append(names, None)
            colors = np.append(colors, [name]*(len(y)+1))

    fig = px.line_mapbox(lat=lats, lon=lons, hover_name=names, mapbox_style="open-street-map", zoom=zoom, color=colors, title=title)
    fig.update_layout(margin={"r":0,"t":50,"l":0,"b":0})
    fig.show()

# %%
turin_gps_df = pd.read_csv('/home/rodrigo/charts/smartcity-tpn/turin-gps.csv')
turin_geo_df = csv_to_geo(turin_gps_df)
make_map(turin_geo_df,11.65,'Routes - {}'.format(scenarios['turin']))
# Out:
# <div>                            <div id="9967a059-359b-4417-8275-55d346f247af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9967a059-359b-4417-8275-55d346f247af")) {                    Plotly.newPlot(                        "9967a059-359b-4417-8275-55d346f247af",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>color=EV1<br>lat=%{lat}<br>lon=%{lon}<extra></extra>","hovertext":["EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV ...

# %%
turin_df = pd.read_csv('/home/rodrigo/charts/smartcity-tpn/turin.csv')

make_boxplot_grouped(turin_df[turin_df['alg'] != 'no-preemption'], 'imp', 'Time-Loss Improvement - {}'.format(scenarios['turin']))
# Out:
# <div>                            <div id="ccfc9c4a-70a9-4885-846d-b67a02400448" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ccfc9c4a-70a9-4885-846d-b67a02400448")) {                    Plotly.newPlot(                        "ccfc9c4a-70a9-4885-846d-b67a02400448",                        [{"marker":{"color":"#3D9970"},"name":"Hyphotetical all-green","type":"box","x":["EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3"],"y":[15.523954550778962,17.26694762191451,17.742830712303423,15.652803958529688,28.42010989010989,17.07690052765292,21.668776371308017,28.82389302384256,64.82277170787809,36.80676383511729,16.815492494795663,21.831171893421367,12.961937046004842,32.58139245236019,20.456445728184857,35.968077286569354,26.517106549364613,19.65738019169329,20.591221458656616,16.553640564506058,26.5551749449474,20.17159034958149,45.68688427299704,18.403019048760036,4.335629304946775,5.051909476661952,4.439624556062912,4.08062218000475,4.877623875481936,4.560991867750967,4.573494917904614,4.619560930721704,4.800109679188374,4.464757992040056,5.222545454545455,4.411499871366092,6.10604410563572,4.874609485941494,4.870435147614384,5.050266903914591,4.805817174515235,4.516145500957244,4.548809212248103,4.710624224886318,4.227841945288754,4.669981187852728,5.553491827637444,4.42063081695967,4.995046702519105,20.304249902075988,14.137908760597496,10.087383240828482,5.36919315403423,6.134547142904521,31.01961712778191,6.086679074714172,7.296256085174939,3.990908485413615,9.301562741760792,6.152836832314642,3.730906880950773,2.6044893762851267,3.5838672580910136,5.5822439157592925,4.378828977836586,16.383346618431542,7.227358709720241,3.864895065823934,5.4554653842300365,5.023406249285698,6.726524254561638]},{"marker":{"color":"#FF4136"},"name":"Kapusta et al (2017)","type":"box","x":["EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3"],"y":[1.4428757948920263,18.41682063915692,11.290975609756098,4.504528512209566,4.276270055014617,5.776050267853546,4.485303551641687,3.129307299149728,7.534230004896173,16.206108580389813,1.638591980410162,6.686087570621469,8.220733994106617,8.18237334137515,8.30680578782811,23.22271714922049,3.219935381000336,35.73183720045645,3.4765959139827727,4.797427492428303,3.3961411725695814,16.965032194155523,3.6492779066608154,-2.867190329590728,1.6206366220813722,2.660342717258262,2.855039453347433,1.8483912209673985,1.61947520238206,1.7423950517136484,1.7642835626066875,3.768274239623593,2.58069325382035,2.576680750129716,2.687026441935983,2.646144326707402,1.64698516663456,1.7114389359129385,2.8461414402064347,2.492191295897828,1.866808650065531,2.5973690213671965,2.738055356145808,3.713162251655629,1.155258370949269,2.8154761904761907,1.8573019998939049,1.7764043185729932,1.7751105809850405,6.920990266610241,7.287822507780344,18.578500903907663,4.231901970478141,6.161300538372216,21.67919004635277,6.252957879791765,1.470466060513372,8.556884599700966,4.592104350239367,3.864355294857023,4.146413832168964,6.314129878984148,-2.401862429798877,2 ...
#
# var gd = document.getElementById('ccfc9c4a-70a9-4885-846d-b67a02400448');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
make_boxplot_grouped(turin_df[turin_df['alg'] != 'no-preemption'], 'perc', 'Time-Loss Improvement - {}'.format(scenarios['turin']))
# Out:
# <div>                            <div id="8411c04f-6988-44e4-8eef-cf4a72d80803" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8411c04f-6988-44e4-8eef-cf4a72d80803")) {                    Plotly.newPlot(                        "8411c04f-6988-44e4-8eef-cf4a72d80803",                        [{"marker":{"color":"#3D9970"},"name":"Hyphotetical all-green","type":"box","x":["EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3"],"y":[93.55834238802366,94.20858844367582,94.36392075078206,93.61136827210392,96.48136476647475,94.14413641175292,95.38506474539967,96.53065601106408,98.45733224042552,97.28310806003026,94.05310311125592,95.41939386084287,92.28510371211668,96.9307634673313,95.11156525777984,97.21975686375262,96.2288494857522,94.91285211839887,95.14356153175363,93.95903278131956,96.23425565045932,95.04253267754494,97.8111880118053,94.56610897728012,76.93529751588677,80.205504381667,77.47557282441004,75.49393313352925,79.49821418115815,78.07494446393079,78.13488332336097,78.35292108932586,79.16714269393351,77.60236945019554,80.85224899039132,77.33197259075666,83.62278452792332,79.48553616686573,79.4679536901376,80.19906632608121,79.1918842584587,77.85722360388876,78.01622461308325,78.77139096094778,76.34727094956003,78.58663750935145,81.9933110367893,77.37879408152524,79.9801671624876,95.07492271409762,92.92681812470732,90.08662627238628,81.3752276867031,83.69887822678741,96.77623358186337,83.57067971343702,86.29434070945136,74.94304859019185,89.24911837114912,83.74733432312053,73.19686521510923,61.60475795734155,72.09718083887233,82.08605687800762,77.16284410600429,93.89624096169103,86.16368662240222,74.12607631077259,81.66975813116379,80.09318875728606,85.13348109431341]},{"marker":{"color":"#FF4136"},"name":"Kapusta et al (2017)","type":"box","x":["EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3"],"y":[30.69396523663824,94.57018114259174,91.14336940790184,77.80011831894302,76.61513451828566,82.68713128129315,77.7049649263095,68.04404603307216,86.72724353583388,93.82948722674826,38.97199473967362,85.04357010826511,87.83563607924923,87.778607033935,87.96167834493866,95.69387167929412,68.94347613617853,97.20137536060636,71.23623151088606,79.15549528203849,70.55481650536389,94.10552253272763,72.59731854965723,-186.7190329590728,38.29585322367286,62.41085806303197,64.97421432031227,45.89889907199263,38.25160159728805,42.60773416358716,43.31976893087847,73.46265328874024,61.250722125938765,61.19038030032795,62.78413995511308,62.20916637437157,39.28299900578982,41.56963599366945,64.86471171554045,59.87466926611893,46.43264589732339,61.499502312781786,63.47772890144784,73.06877717088396,13.439276862516392,64.48202959830867,46.15845995658632,43.70650929269796,43.66548142341182,85.55120060167663,86.27848031517756,94.61743439273044,76.36996303373694,83.76966041873693,95.3872815457502,84.00756859035005,31.994350168756835,88.3135037250012,78.22349137279787,74.12246225571246,75.88277387457715,84.16250506141179,-140.18624297988768,61.9376570744352,96.8645529621884,75.6262 ...
#
# var gd = document.getElementById('8411c04f-6988-44e4-8eef-cf4a72d80803');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
make_boxplot(turin_df[turin_df['alg'] == 'no-preemption'], 'tl', 'Time-Loss - No Preemption - {}'.format(scenarios['turin']))
# Out:
# <div>                            <div id="72ed732b-9ce7-474d-acbe-452cf4997ebe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72ed732b-9ce7-474d-acbe-452cf4997ebe")) {                    Plotly.newPlot(                        "72ed732b-9ce7-474d-acbe-452cf4997ebe",                        [{"name":"EV1","type":"box","y":[2284.87,1325.28,1538.19,2615.96,3425.24,1534.75,3849.12,1536.1,1434.02,1534.4,1747.65,1746.07,1325.45,2170.16,2170.62,1328.61,1338.32,2691.25,1851.72,5636.34,1857.74,3232.37,2586.23,1638.74]},{"name":"EV2","type":"box","y":[342.95,341.98,347.62,342.12,351.41,448.55,350.97,448.5,352.95,347.54,346.98,359.05,340.59,341.58,350.02,353.84,347.74,357.17,347.76,343.67,350.12,343.27,348.09,346.2,341.85]},{"name":"EV3","type":"box","y":[1323.72,1105.02,6220.41,1537.2,1090.75,2980.62,759.99,1852.25,2177.82,2083.3,1750.98,1106.79,2197.69,1635.43,1849.75,1198.39,5343.92,2518.12,1633.53,9171.26,906.87,1202.32]}],                        {"template":{"data":{"scatter":[{"type":"scatter"}]}},"title":{"text":"Time-Loss - No Preemption - Turin TuSTScenario"},"yaxis":{"title":{"text":"Time-Loss (s)"}}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('72ed732b-9ce7-474d-acbe-452cf4997ebe');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
make_boxplot_grouped(turin_df[turin_df['alg'] != 'no-preemption'], 'tl', 'Time-Loss - Solutions - {}'.format(scenarios['turin']))
# Out:
# <div>                            <div id="1189b9bc-5d90-4dd7-8222-6dc4629592d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1189b9bc-5d90-4dd7-8222-6dc4629592d7")) {                    Plotly.newPlot(                        "1189b9bc-5d90-4dd7-8222-6dc4629592d7",                        [{"marker":{"color":"#3D9970"},"name":"Hyphotetical all-green","type":"box","x":["EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3"],"y":[85.37,83.05,86.48,84.88,91.0,102.34,80.58,79.27,86.95,87.82,91.27,84.82,103.25,80.29,131.56,95.23,81.84,78.25,93.0,90.22,80.07,81.74,81.24,84.25,83.47,79.85,70.7,78.84,84.22,70.03,75.01,76.74,76.07,72.94,77.89,68.75,77.74,73.46,70.42,71.47,67.44,72.2,78.35,76.42,72.57,82.25,74.42,80.76,77.36,70.66,306.36,123.85,295.48,286.3,301.53,292.29,295.66,413.71,285.53,300.28,129.26,288.73,301.04,296.18,281.16,291.8,304.35,292.97,302.3,326.18,301.33,286.37,299.43,437.49,134.82]},{"marker":{"color":"#FF4136"},"name":"Kapusta et al (2017)","type":"box","x":["EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3"],"y":[1064.61,146.13,164.0,574.14,434.43,248.27,342.94,424.57,347.21,133.91,816.75,198.24,186.65,265.28,275.06,139.19,476.64,157.74,502.69,802.33,482.53,201.9,478.47,3799.83,804.5,214.57,130.72,122.93,187.72,214.94,197.24,199.18,119.02,134.15,134.91,129.34,129.29,207.64,206.75,124.01,144.07,183.12,131.51,125.37,120.8,296.86,124.32,188.51,191.73,201.21,236.3,298.83,284.49,287.64,283.18,284.19,286.93,372.79,295.82,2026.99,294.28,288.26,286.41,370.73,293.35,295.99,5003.8,289.27,287.56,293.05,288.28,458.42,288.31,286.22,286.84]},{"marker":{"color":"#FF851B"},"name":"TPN","type":"box","x":["EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3"],"y":[109.98,161.99,546.53,130.42,117.95,101.1,314.61,104.33,102.13,109.72,129.11,116.75,133.0,112.29,264.49,129.77,139.52,86.37,240.39,103.67,1195.2,84.09,162.2,269.88,123.43,69.6,79.45,71.01,71.72,91.49,80.99,75.29,69.9,70.47,78.08,72.47,69.62,77.76,76.88,74.49,88.59,73.27,69.94,75.44,77.61,68.1,71.33,79.4,70.2,72.09,118.01,116.87,60.73,117.81,82.03,94.16,117.73,76.33,117.96,117.89,82.51,116.78,117.83,117.93,75.92,117.14,116.61,80.88,118.27,118.22,121.98,117.4,117.13,118.08,117.52]}],                        {"boxmode":"group","template":{"data":{"scatter":[{"type":"scatter"}]}},"title":{"text":"Time-Loss - Solutions - Turin TuSTScenario"},"yaxis":{"title":{"text":"Time-Loss (s)"}}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('1189b9bc-5d90-4dd7-8222-6dc4629592d7');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
make_boxplot_grouped(turin_df[turin_df['alg'] != 'no-preemption'], 'rt', 'Runtime - Solutions - {}'.format(scenarios['turin']))
# Out:
# <div>                            <div id="1ef48772-a055-44a2-b8c4-d0d324e2ccc8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ef48772-a055-44a2-b8c4-d0d324e2ccc8")) {                    Plotly.newPlot(                        "1ef48772-a055-44a2-b8c4-d0d324e2ccc8",                        [{"marker":{"color":"#3D9970"},"name":"Hyphotetical all-green","type":"box","x":["EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3"],"y":[25539.96,17123.93,26103.28,26529.53,26093.39,26383.68,20471.15,17586.44,26524.31,26371.37,19739.87,17946.39,26259.04,26511.49,24433.33,26230.52,26116.37,24791.57,26182.13,19385.42,26593.54,22792.48,25245.04,25746.92,26098.82,18340.47,19721.38,27193.71,18358.83,26895.41,27214.32,21997.88,24350.24,18166.99,18625.86,27006.07,27149.83,18021.29,26768.03,26440.13,24374.56,27023.89,18780.76,26589.34,26919.03,25324.09,20300.28,26616.28,26554.68,17857.8,26327.5,17112.91,24626.16,25970.21,20091.19,19431.68,25953.3,27293.72,24178.84,26208.37,14803.83,17647.64,26359.3,25990.16,25352.67,19671.29,26265.57,24005.43,20650.27,24909.28,17378.18,17351.98,26201.15,27370.24,22727.62]},{"marker":{"color":"#FF4136"},"name":"Kapusta et al (2017)","type":"box","x":["EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3"],"y":[27294.52,23929.99,21131.71,29189.74,22011.52,22651.65,27954.8,28667.14,22169.77,26331.27,29954.9,22496.6,26718.68,27618.25,27574.8,26972.19,27776.26,22178.88,28694.56,26860.9,26411.94,22632.66,25112.56,34542.87,27006.31,20805.23,26280.38,24699.09,23098.12,28083.09,26527.85,27695.0,20949.8,18846.34,23451.53,26869.64,18864.88,23391.81,27984.38,18632.58,27435.03,20561.54,27016.11,18876.19,22410.79,28492.88,20931.78,27496.73,19496.47,27802.55,25596.46,21836.09,24929.68,19557.87,25714.28,16675.46,20468.37,26498.05,25136.97,32283.56,22144.49,25209.46,26257.92,23292.47,20923.17,24691.43,34144.25,17232.41,24210.32,24602.69,16674.2,27496.36,25165.76,25920.9,24134.33]},{"marker":{"color":"#FF851B"},"name":"TPN","type":"box","x":["EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3"],"y":[17707.06,27096.82,26192.23,21761.19,19413.52,25690.84,27889.45,25863.54,20355.6,21121.44,20463.07,18253.6,26674.68,19903.44,22118.38,23076.02,26780.03,19975.01,27224.75,19011.91,29577.49,24031.49,26972.68,27136.58,25991.75,20811.08,18057.4,25917.63,26340.98,27202.64,18246.41,24403.54,26586.78,26824.06,26841.28,25281.97,18139.92,26853.94,24970.34,26894.38,27216.31,24790.04,27203.01,18082.85,19101.92,21008.4,23808.92,26621.5,17795.98,27062.51,23091.32,23498.43,15303.98,23309.62,18481.44,18249.19,20567.18,21834.06,23522.39,16753.7,13900.1 ...
#
# var gd = document.getElementById('1ef48772-a055-44a2-b8c4-d0d324e2ccc8');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>
