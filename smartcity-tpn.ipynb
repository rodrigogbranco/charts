# %% [markdown]
# # Partial Data - Smartcity TPN Traffic Light Preemption

# %% [markdown]
# First, we need to import some Python modules. All charts-related functions are in our [helper file](charts_helper/helper.py).

# %%
import pandas as pd
import triscale
import sys
sys.path.append('/home/rodrigo/charts')

from charts_helper import helper

# %% [markdown]
# ## Getting started
#
# We need to define the experiment parameters, considering the experiment's runtime durations and desired confidence intervals.

# %% [markdown]
# Using  [_Triscale_](https://github.com/romain-jacob/triscale) [[Paper]](http://doi.org/10.5281/zenodo.3464273)., we see that we need at least 25 samples to obtain a confidence level of 90% at the 15th percentile, allowing to discard the worst outlier. Without the outlier exclusion, 15 samples are enough to get the same confidence level at the same percentile.

# %%
percentile = 15
confidence = 90
triscale.experiment_sizing(
    percentile, 
    confidence,
    robustness=1,
    verbose=True);
# Out:
# A one-sided bound of the 	15-th percentile
# with a confidence level of	90 %
# requires a minimum of 		25 samples
# with the worst 			1 run(s) excluded

# %% [markdown]
# Triscale also informs us that the confidence level at the desired percentile is symmetric.

# %%
percentile = 15 
confidence = 90 # the confidence level, in %

if (triscale.experiment_sizing(percentile,confidence,robustness=1) == 
    triscale.experiment_sizing(100-percentile,confidence,robustness=1)):
    print("It takes the same number of samples to estimate \
the \n{}-th and \n{}-th percentiles.".format(percentile, 100-percentile))
# Out:
# It takes the same number of samples to estimate the
# 15-th and
# 85-th percentiles.

# %% [markdown]
# ## _Turin TuSTScenario_
#
# This scenario was adapted from [this repository](https://github.com/marcorapelli/TuSTScenario) [[Paper]](https://ieeexplore.ieee.org/abstract/document/8958652). From those files, some minor changes have been made (the original work used mesoscopic simulation).

# %% [markdown]
# 3 EVs were chosen to evaluate our proposal. There is nothing special in those routes, but we avoid low-priority streets. We  don't want leader vehicles being blocked, which raises the global timeloss and can happen with any preemption strategy (including No Preemption one, that does nothing). A fair comparison requires no blocking situation excluding, of course, the ones caused by traffic jams. We get the GPS position of our EVs in the simulation. The EV's routes can be checked below:

# %%
df = pd.read_csv('/home/rodrigo/charts/smartcity-tpn/turin-gps.csv')
helper.make_map(df,10,helper.make_title('route','turin'))
# Out:
# <div>                            <div id="3b432212-e511-4e4f-a333-151c708a1097" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b432212-e511-4e4f-a333-151c708a1097")) {                    Plotly.newPlot(                        "3b432212-e511-4e4f-a333-151c708a1097",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>color=Experiment Area<br>lat=%{lat}<br>lon=%{lon}<extra></extra>","hovertext":["Experiment Area","Experiment Area","Experiment Area","Experiment Area","Experiment Area",null],"lat":[45.171751,45.171751,44.96828,44.96828,45.171751,null],"legendgroup":"Experiment Area","line":{"color":"#1F77B4"},"lon":[7.515782,7.773786,7.773786,7.515782,7.515782,null],"mode":"lines","name":"Experiment Area","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"<b>%{hovertext}</b><br><br>color=EV1<br>lat=%{lat}<br>lon=%{lon}<extra></extra>","hovertext":["EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","E ...

# %% [markdown]
# We restricted the entry window of vehicles to 6h-8h AM. One simulation (with a pre-defined seed) was done from 6h to EV's entry time (which is 7h AM). The simulation state was saved. After that, the EV was inserted in the network and a new seed is set to each simulation, which runs independently.

# %% [markdown]
# Hence, Our experiment, for that scenario, is:
#
# _Number of Vehicles to be inserted in the original scenario (24h):_ **2,202,814**
#
# _Number of Vehicles to be inserted in the our version (6h-8h):_ **175,873**

#
# var gd = document.getElementById('ddfcb7a2-e984-4356-8685-5a44449ab7d1');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# In the sequence, we can see the Time-Loss variation only in the No Preemption version (to see our improvement potentials and limits). Fo example, No Preemption version for EV2 vary between 340 and 360 seconds (with one 448.55 second outlier). In this case, we can obtain good percentage, as we did, but not many times better (see the first chart), at least comparing with the other two EVS.

# %%
helper.make_boxplot(df_no_preemption, 'tl', helper.make_title('tl-no-preemption','turin'))
# Out:
# <div>                            <div id="7202df4b-9589-455c-b7d6-04c0ff92124e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7202df4b-9589-455c-b7d6-04c0ff92124e")) {                    Plotly.newPlot(                        "7202df4b-9589-455c-b7d6-04c0ff92124e",                        [{"name":"EV1","type":"box","y":[2284.87,1325.28,1538.19,2615.96,3425.24,1534.75,3849.12,1536.1,1434.02,1534.4,1747.65,1746.07,1325.45,2170.16,2170.62,1328.61,1338.32,2691.25,1851.72,5636.34,1857.74,3232.37,2586.23,1638.74]},{"name":"EV2","type":"box","y":[342.95,341.98,347.62,342.12,351.41,448.55,350.97,448.5,352.95,347.54,346.98,359.05,340.59,341.58,350.02,353.84,347.74,357.17,347.76,343.67,350.12,343.27,348.09,346.2,341.85]},{"name":"EV3","type":"box","y":[1323.72,1105.02,6220.41,1537.2,1090.75,2980.62,759.99,1852.25,2177.82,2083.3,1750.98,1106.79,2197.69,1635.43,1849.75,1198.39,5343.92,2518.12,1633.53,9171.26,906.87,1202.32]}],                        {"template":{"data":{"scatter":[{"type":"scatter"}]}},"title":{"text":"Time-Loss - No Preemption - Turin TuSTScenario"},"yaxis":{"title":{"text":"Time-Loss (s)"}}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('7202df4b-9589-455c-b7d6-04c0ff92124e');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# To get a better understand of the situation, we can compare Time-Loss as is between the solutions. With that, we can capture the scale of our improvement (the less the better).

# %%
helper.make_boxplot_grouped(df_algs, 'tl', helper.make_title('tl-algs','turin'))
# Out:
# <div>                            <div id="bf28fddb-2f1e-456d-8ca2-03b4a2976b72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf28fddb-2f1e-456d-8ca2-03b4a2976b72")) {                    Plotly.newPlot(                        "bf28fddb-2f1e-456d-8ca2-03b4a2976b72",                        [{"marker":{"color":"#FF851B"},"name":"Kapusta et al (2017)","type":"box","x":["EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3"],"y":[1064.61,146.13,164.0,574.14,434.43,248.27,342.94,424.57,347.21,133.91,816.75,198.24,186.65,265.28,275.06,139.19,476.64,157.74,502.69,802.33,482.53,201.9,478.47,3799.83,804.5,214.57,130.72,122.93,187.72,214.94,197.24,199.18,119.02,134.15,134.91,129.34,129.29,207.64,206.75,124.01,144.07,183.12,131.51,125.37,120.8,296.86,124.32,188.51,191.73,201.21,236.3,298.83,284.49,287.64,283.18,284.19,286.93,372.79,295.82,2026.99,294.28,288.26,286.41,370.73,293.35,295.99,5003.8,289.27,287.56,293.05,288.28,458.42,288.31,286.22,286.84]},{"marker":{"color":"#FF4136"},"name":"TPN","type":"box","x":["EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3"],"y":
type":"box","x":["EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3"],"y":[17707.06,27096.82,26192.23,21761.19,19413.52,25690.84,27889.45,25863.54,20355.6,21121.44,20463.07,18253.6,26674.68,19903.44,22118.38,23076.02,26780.03,19975.01,27224.75,19011.91,29577.49,24031.49,26972.68,27136.58,25991.75,20811.08,18057.4,25917.63,26340.98,27202.64,18246.41,24403.54,26586.78,26824.06,26841.28,25281.97,18139.92,26853.94,24970.34,26894.38,27216.31,24790.04,27203.01,18082.85,19101.92,21008.4,23808.92,26621.5,17795.98,27062.51,23091.32,23498.43,15303.98,23309.62,18481.44,18249.19,20567.18,21834.06,23522.39,16753.7,13900.11,23378.04,22533.89,14886.19,22771.32,14653.1,15431.39,13685.33,14877.21,21778.71,14733.9,21711.57,22628.54,18306.84,22385.29]},{"marker":{"color":"#3D9970"},"name":"Hyphotetical all-green","type":"box","x":["EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3","EV3"],"y":[25539.96,17123.93,26103.28,26529.53,26093.39,26383.68,20471.15,17586.44,26524.31,26371.37,19739.87,17946.39,26259.04,26511.49,24433.33,26230.52,26116.37,24791.57,26182.13,19385.42,26593.54,22792.48,25245.04,25746.92,26098.82,18340.47,19721.38,27193.71,18358.83,26895.41,27214.32,21997.88,24350.24,18166.99,18625.86,27006.07,27149.83,18021.29,26768.03,26440.13,24374.56,27023.89,18780.76,26589.34,26919.03,25324.09,20300.28,26616.28,26554.68,17857.8,26327.5,17112.91,24626.16,25970.21,20091.19,19431.68,25953.3,27293.72,24178.84,26208.37,14803.83 ...
#
# var gd = document.getElementById('27dd0385-f4a8-4a16-9313-3407c1d97323');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# ## _TAPAS Cologne_
#
# This scenario was adapted from [this page](https://sumo.dlr.de/docs/Data/Scenarios/TAPASCologne.html) [[Paper]](https://elib.dlr.de/45058/2/SRL_81_-_Beitrag_Varschen.pdf). The same process used in Turin TuSTScenario was used here. So, we'll state the differences.

# %% [markdown]
# _Number of Vehicles to be inserted in the original scenario (24h):_ **1,549,612**
#
# _Number of Vehicles to be inserted in the our version (6h-8h):_ **252,754**

# %% [markdown]
# | EV       |      Distance         |  Traffic Lights |
# |----------|:---------------------:|----------------:|
# | EV1      |        8,351.42m       |       26        |
# | EV2      |         5,044.34m      |       27        |
# | EV3      |          6,344.31     |         24      |

# %% [markdown]
# The following can be interpreted like the previous scenario. You can see the map, routes and our results.

# %%
df = pd.read_csv('/home/rodrigo/charts/smartcity-tpn/cologne-gps.csv')
helper.make_map(df,9.25,helper.make_title('route','cologne'))
# Out:
# <div>                            <div id="2856f86c-2ff0-445a-8232-516bf7b4bcc5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2856f86c-2ff0-445a-8232-516bf7b4bcc5")) {                    Plotly.newPlot(                        "2856f86c-2ff0-445a-8232-516bf7b4bcc5",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>color=Experiment Area<br>lat=%{lat}<br>lon=%{lon}<extra></extra>","hovertext":["Experiment Area","Experiment Area","Experiment Area","Experiment Area","Experiment Area",null],"lat":[51.109564,50.818858,50.818858,51.109564,51.109564,null],"legendgroup":"Experiment Area","line":{"color":"#1F77B4"},"lon":[6.800044,6.800044,7.212986,7.212986,6.800044,null],"mode":"lines","name":"Experiment Area","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"<b>%{hovertext}</b><br><br>color=EV1<br>lat=%{lat}<br>lon=%{lon}<extra></extra>","hovertext":["EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1","EV1", ...

# %%
df = pd.read_csv('/home/rodrigo/charts/smartcity-tpn/cologne.csv')
df_algs = df[df['alg'] != 'no-preemption']
df_no_preemption = df[df['alg'] == 'no-preemption']

# %%
helper.make_boxplot_grouped(df_algs, 'imp', helper.make_title('tl-imp','cologne'))
# Out:
# <div>                            <div id="a5c1cec2-9d3a-4d00-ac84-afe4ecbadaba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a

# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# ## _Metro OD SP 2017_
#
# This scenario was made in this work, using Survey data from Metro SP by the year of 2017 (available [here](https://transparencia.metrosp.com.br/dataset/pesquisa-origem-e-destino/resource/4362eaa3-c0aa-410a-a32b-37355c091075)).

# %% [markdown]
# The coverage area is the Metropolitan Region of São Paulo, which includes 39 cities composing a total of 517 survey zones (see picture below). A trip in this survey contains a Origin zone, a Destination Zone, a travel mode, and a depart time (within a daily 24 time window). The original data is a sample of ~90k daily trips , which corresponds to 28M motorized (includind shared) trips.

# %% [markdown]
# | ![Coverage Area - OD Survey - Metro SP 2017](./smartcity-tpn/coverage-area.png) |
# |:--:|
# | *Source: [This PDF, page 33](https://transparencia.metrosp.com.br/dataset/pesquisa-origem-e-destino/resource/b3d93105-f91e-43c6-b4c0-8d9c617a27fc)* |

# %% [markdown]
# We use this data to generate a 11M vehicle trips (for the shared trips, we considered an average load of 40 passengers by vehicle), including ordinary automobiles, motorcycles and buses. This complete SUMO Network and files were available [here](https://gitlab.com/rodrigo.g.branco/metro-od-2017).

# %% [markdown]
# However, SUMO can't handle this amount of data in a reasonable running time. Because of that, we limited our experiment to a area known as Expanded Center of São Paulo (we'll present this area when the EVs are introduced). Beside that, the normal window of 6h-8h like the previous scenarios, here, is too much for SUMO (aprox. 1M trips). So, our depart windows in this very scenario is, in fact, 6h30-7h30.

# %% [markdown]
# With that in mind, we have this configuration:

# %% [markdown]
# _Number of Vehicles to be inserted in the original (complete) scenario (24h):_ **13,215,558**
#
# _Number of Vehicles to be inserted in the our (restricted to Expanded Center) version  (6h30-7h30):_ **601,114**

# %% [markdown]
# | EV       |      Distance         |  Traffic Lights |
# |----------|:---------------------:|----------------:|
# | EV1      |        17,760.26m      |        86      |
# | EV2      |       6,912.21m        |        15       |
# | EV3      |      11,486.74m          |       61        |

# %% [markdown]
# Now we can see our EVs routes, plus the limit of the expanded center.

# %%
df = pd.read_csv('/home/rodrigo/charts/smartcity-tpn/expanded-sp-gps.csv')
helper.make_map(df, 11.10, helper.make_title('route','metro-od-2017'))
# Out:
# <div>                            <div id="8e02957b-cb2d-422d-aede-b1e13dccd009" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e02957b-cb2d-422d-aede-b1e13dccd009")) {                    Plotly.newPlot(                        "8e02957b-cb2d-422d-aede-b1e13dccd009",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>color=Expanded Center Of S\u00e3o Paulo<br>lat=%{lat}<br>lon=%{lon}<extra></extra>","hovertext":["Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Center Of S\u00e3o Paulo","Expanded Cente ...

# %%
df = pd.read_csv('/home/rodrigo/charts/smartcity-tpn/expanded-center.csv')
df_algs = df[df['alg'] != 'no-preemption']
df_no_preemption = df[df['alg'] == 'no-preemption']

# %%
helper.make_boxplot_grouped(df_algs, 'imp', helper.make_title('tl-imp', 'metro-od-2017'))
# Out:
# <div>                            <div id="16c89643-e11c-4376-ab0b-2c0642817a5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16c89643-e11c-4376-ab0b-2c0642817a5a")) {                    Plotly.newPlot(                        "16c89643-e11c-4376-ab0b-2c0642817a5a",                        [{"marker":{"color":"#FF851B"},"name":"Kapusta et al (2017)","type":"box","x":["EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV
d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("949aec56-b8e3-4084-a87d-ed1ed5f094dd")) {                    Plotly.newPlot(                        "949aec56-b8e3-4084-a87d-ed1ed5f094dd",                        [{"name":"EV2","type":"box","y":[2982.48,2800.55,3342.59,2982.0,2891.0,2979.62,3342.39,2888.91,2982.1,2711.89,2618.32,2535.81,3247.89,2347.54,2531.91]}],                        {"template":{"data":{"scatter":[{"type":"scatter"}]}},"title":{"text":"Time-Loss - No Preemption - Metro OD 2017 Survey (Expanded Center of S\u00e3o Paulo)"},"yaxis":{"title":{"text":"Time-Loss (s)"}}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('949aec56-b8e3-4084-a87d-ed1ed5f094dd');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
helper.make_boxplot_grouped(df_algs, 'tl', helper.make_title('tl-algs', 'metro-od-2017'))
# Out:
# <div>                            <div id="1fa90c76-ef7a-4025-b5fe-59dc693455ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1fa90c76-ef7a-4025-b5fe-59dc693455ee")) {                    Plotly.newPlot(                        "1fa90c76-ef7a-4025-b5fe-59dc693455ee",                        [{"marker":{"color":"#FF851B"},"name":"Kapusta et al (2017)","type":"box","x":["EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2"],"y":[2587.07,3219.42,3053.71,2866.7,3578.55,3230.47,2907.26,2825.84,2703.39,3261.53,2678.3,2877.98,3224.24,3666.56,3223.14]},{"marker":{"color":"#FF4136"},"name":"TPN","type":"box","x":["EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2"],"y":[464.78,593.16,817.54,984.29,480.91,499.48,508.66,381.74,642.06,752.55,320.3,324.81,153.67,909.37,571.31]},{"marker":{"color":"#3D9970"},"name":"Hyphotetical all-green","type":"box","x":["EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2"],"y":[579.79,107.06,99.77,125.45,187.44,816.59,186.78,681.01,100.39,157.65,74.87,98.63,5072.41,741.04,186.77]}],                        {"boxmode":"group","template":{"data":{"scatter":[{"type":"scatter"}]}},"title":{"text":"Time-Loss - Solutions - Metro OD 2017 Survey (Expanded Center of S\u00e3o Paulo)"},"yaxis":{"title":{"text":"Time-Loss (s)"}}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('1fa90c76-ef7a-4025-b5fe-59dc693455ee');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
helper.make_boxplot_grouped(df_algs, 'rt', helper.make_title('runtime','metro-od-2017'))
# Out:
# <div>                            <div id="a3a01487-b5fd-492b-b005-4fe1c181d931" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3a01487-b5fd-492b-b005-4fe1c181d931")) {                    Plotly.newPlot(                        "a3a01487-b5fd-492b-b005-4fe1c181d931",                        [{"marker":{"color":"#FF851B"},"name":"Kapusta et al (2017)","type":"box","x":["EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2"],"y":[69477.47,76940.23,80205.85,79550.39,62690.39,58363.21,72132.53,72311.89,75018.51,90292.14,58042.82,73644.64,72343.53,82697.05,77607.4]},{"marker":{"color":"#FF4136"},"name":"TPN","type":"box","x":["EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2"],"y":[43348.22,44580.7,47731.5,49186.51,43071.79,43322.41,42746.72,41267.7,45016.96,46445.7,45279.74,40397.42,9455.17,39833.66,39526.68]},{"marker":{"color":"#3D9970"},"name":"Hyphotetical all-green","type":"box","x":["EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2","EV2"],"y":[41078.12,9305.44,9223.65,38156.39,39041.92,39411.4,39091.79,46152.04,36231.06,44898.45,9067.99,9290.7,98471.27,46308.48,34844.42]}],                        {"boxmode":"group","template":{"data":{"scatter":[{"type":"scatter"}]}},"title":{"text":"Runtime - Solutions - Metro OD 2017 Survey (Expanded Center of S\u00e3o Paulo)"},"yaxis":{"title":{"text":"Runtime (s)"}}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('a3a01487-b5fd-492b-b005-4fe1c181d931');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>
